# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
from datetime import datetime,date,timedelta
import pickle

# %%
# %%time
print('pickle read')
allwind = pd.read_pickle('ppoint_raw_2021-06-01_2022-10-23.pkl')
# Out:
# pickle read
# CPU times: user 73.6 ms, sys: 33.5 ms, total: 107 ms
# Wall time: 126 ms

# %%
#%%time
#allwind = pd.read_csv('ppoint_raw_2021-06-01_2022-10-23.csv')

# %%
allwind['Month'] = pd.DatetimeIndex(allwind['Date']).month_name().str[:3]

# %%
allwind.loc[(allwind.Time.str.startswith(("10:","11:")) & allwind.Time.str.endswith("PM")) |\
            (allwind.Time.str.startswith(("12:","1:","2:","3:","4:","5:")) & allwind.Time.str.endswith("AM")) ,\
            "Daypart"] = "Overnight"

allwind.loc[allwind.Time.str.startswith(("6:","7:","8:","9:")) & \
            allwind.Time.str.endswith("AM"), \
            "Daypart"] = "Morning"

allwind.loc[(allwind.Time.str.startswith(("10:","11:")) & allwind.Time.str.endswith("AM")) |\
            (allwind.Time.str.startswith(("12:","1:")) & allwind.Time.str.endswith("PM")) ,\
            "Daypart"] = "Midday"

allwind.loc[allwind.Time.str.startswith(("2:","3:","4:","5:")) & \
            allwind.Time.str.endswith("PM"), \
            "Daypart"] = "Afternoon"

allwind.loc[allwind.Time.str.startswith(("6:","7:","8:","9:")) & \
            allwind.Time.str.endswith("PM"), \
            "Daypart"] = "Evening"

# %%
allwind.loc[allwind.Month.isin(['Dec','Jan','Feb']) ,\
            "Season"] = "Winter"

allwind.loc[allwind.Month.isin(['Mar','Apr','May']) ,\
            "Season"] = "Spring"
             
allwind.loc[allwind.Month.isin(['Jun','Jul','Aug']) ,\
            "Season"] = "Summer"
             
allwind.loc[allwind.Month.isin(['Sep','Oct','Nov']) ,\
            "Season"] = "Fall"

# %%
allwind = allwind[['Date','Time','Season','Month','Daypart','Temp','Wind','Azimuth','Speed','Gust']]

# %%
allwind[::len(allwind)//10]
# Out:
#            Date      Time  Season Month    Daypart  Temp  Wind  Azimuth  \
# 0    2021-06-01  12:04 AM  Summer   Jun  Overnight  52.8   WSW    247.5
# 63   2021-07-22   5:18 AM  Summer   Jul  Overnight  54.7   WSW    247.5
# 173  2021-09-10   2:29 PM    Fall   Sep  Afternoon  69.7    SE    135.0
# 220  2021-10-31   6:24 PM    Fall   Oct    Evening  58.1  West    270.0
# 281  2021-12-20  11:29 PM  Winter   Dec  Overnight  44.8   WNW    292.5
# 253  2022-02-10   9:13 PM  Winter   Feb    Evening  55.5  West    270.0
# 32   2022-04-03   2:44 AM  Spring   Apr  Overnight  48.4   WNW    292.5
# 203  2022-05-23   5:24 PM  Spring   May  Afternoon  62.0   ESE    112.5
# 206  2022-07-14   5:14 PM  Summer   Jul  Afternoon  67.1   ESE    112.5
# 6    2022-09-03  12:34 AM    Fall   Sep  Overnight  58.4  East     90.0
# 287  2022-10-23  11:59 PM    Fall   Oct  Overnight  51.1    NW    315.0
#
#      Speed  Gust
# 0      0.2   1.7
# 63     0.1   0.4
# 173    3.5   7.4
# 220    0.0   0.4
# 281    1.0   1.7
# 253    0.1   0.2
# 32     1.2   1.9
# 203    2.9   7.1
# 206    3.9  10.0
# 6      0.0   0.0
# 287    0.6   1.6

# %%
allwind.to_csv('ppoint_raw_2021-06-01_2022-10-23.csv')
allwind.to_pickle('ppoint_raw_2021-06-01_2022-10-23.pkl')
